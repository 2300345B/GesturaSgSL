# %%
import subprocess
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import re

# Configuration
img_size = 800
batch_size = 16
epochs = 50
dataset_yaml = os.path.abspath("dataset.yaml")
weights = os.path.abspath("yolov5s.pt")
model_name = "sgsl_model_improved v3"

print("🚀 Starting YOLOv5 training...\n")

# Run YOLOv5 training with live log processing
try:
    process = subprocess.Popen(
        [
            "python", "yolov5/train.py",
            "--img", str(img_size),
            "--batch", str(batch_size),
            "--epochs", str(epochs),
            "--data", dataset_yaml,
            "--weights", weights,
            "--name", model_name,
            "--cache"
        ],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True
    )

    current_epoch = None
    for line in process.stdout:
        line = line.strip()

        # Clean YOLO epoch log (matches e.g. "1/29 ...")
        epoch_match = re.match(r'^(\d+)/(\d+)\s+(.*)', line)
        if epoch_match:
            epoch_num = epoch_match.group(1)
            epoch_total = epoch_match.group(2)
            epoch_data = epoch_match.group(3)
            print(f"📘 Epoch {epoch_num}/{epoch_total} — {epoch_data}")
        elif 'all' in line and 'mAP@' in line:
            # Prints metrics like Precision / Recall / mAP
            print(f"🔍 {line}")
        elif 'train/box_loss' in line or 'val/box_loss' in line:
            print(f"📊 {line}")
        else:
            # Optional: uncomment below if you want to see all raw logs too
            # print(line)
            pass

    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, process.args)

except subprocess.CalledProcessError as e:
    print("❌ Training failed!")
    print(e)
    exit(1)

run_folder = f"runs/train/{model_name}"
print(f"\n✅ Training complete. Check the folder: {run_folder}/")
# Out:
# 🚀 Starting YOLOv5 training...
#
# 📘 Epoch 0/49 — 0G     0.1263    0.04432     0.0719         36        800:   0%|          | 0/15 [00:25<?, ?it/s]
# 📘 Epoch 0/49 — 0G     0.1263    0.04432     0.0719         36        800:   7%|6         | 1/15 [00:25<05:50, 25.07s/it]C:\Users\1MP25399\Documents\GitHub\GesturaSgSL\Kahya\sgsl_yolo\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# 📘 Epoch 0/49 — 0G     0.1281    0.04334    0.07153         31        800:   7%|6         | 1/15 [00:38<05:50, 25.07s/it]
# 📘 Epoch 0/49 — 0G     0.1281    0.04334    0.07153         31        800:  13%|#3        | 2/15 [00:38<03:54, 18.02s/it]C:\Users\1MP25399\Documents\GitHub\GesturaSgSL\Kahya\sgsl_yolo\yolov5\train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
from IPython.display import Image, display
import os
results_path = "C:\\Users\\1MP25399\\Documents\\GitHub\\GesturaSgSL\\Kahya\\sgsl_yolo\\yolov5\\runs\\train\\sgsl_model_improved v3\\results.png"

if os.path.exists(results_path):
    display(Image(filename=results_path))
else:
    print("❌ results.png not found.")

# %%
conf_matrix_path =  "C:\\Users\\1MP25399\\Documents\\GitHub\\GesturaSgSL\\Kahya\\sgsl_yolo\\yolov5\\runs\\train\\sgsl_model_improved v3\\confusion_matrix.png"


if os.path.exists(conf_matrix_path):
    display(Image(filename=conf_matrix_path))
else:
    print("ℹ️ confusion_matrix.png not found (maybe not generated if too few classes or images).")

# %%
import pandas as pd

csv_path = r"C:\Users\1MP25399\Documents\GitHub\GesturaSgSL\Kahya\sgsl_yolo\yolov5\runs\train\sgsl_model_improved v3\results.csv"
df = pd.read_csv(csv_path)
print("📄 Columns in results.csv:")
print(df.columns.tolist())
# Out:
# 📄 Columns in results.csv:
# ['               epoch', '      train/box_loss', '      train/obj_loss', '      train/cls_loss', '   metrics/precision', '      metrics/recall', '     metrics/mAP_0.5', 'metrics/mAP_0.5:0.95', '        val/box_loss', '        val/obj_loss', '        val/cls_loss', '               x/lr0', '               x/lr1', '               x/lr2']

# %%
# Get last row
final_row = df.iloc[-1]

    # Helper function to get metric values safely
def safe_get(col_part, decimals=4):
        for col in df.columns:
            if col_part in col:
                return f"{final_row[col]:.{decimals}f}"
        return "N/A"

print("\n📊 Final Evaluation Metrics:")
print(f"Epoch: {int(final_row.name) + 1}")
print(f"  🔹 mAP@0.5:      {safe_get('mAP_0.5')}")
print(f"  🔹 Precision:    {safe_get('precision')}")
print(f"  🔹 Recall:       {safe_get('recall')}")
# Out:
# 📊 Final Evaluation Metrics:
# Epoch: 50
#   🔹 mAP@0.5:      0.9950
#   🔹 Precision:    0.8630
#   🔹 Recall:       1.0000

# %%
# 📈 Plot available training metrics
plt.figure(figsize=(12, 5))
# Plot mAP / Precision / Recall if present
plt.subplot(1, 2, 1)
plotted = False
for col in df.columns:
    if any(x in col for x in ['mAP_0.5', 'precision', 'recall']):
        plt.plot(df[col], label=col)
        plotted = True
    if plotted:
        plt.title("Validation Metrics")
        plt.xlabel("Epoch")
        plt.ylabel("Score")
        plt.grid(True)
        plt.legend()
    else:
        plt.text(0.5, 0.5, "No validation metrics found", ha='center')

# Plot losses
plt.subplot(1, 2, 2)
plotted = False
for col in df.columns:
    if 'loss' in col:
        plt.plot(df[col], label=col)
        plotted = True
    if plotted:
        plt.title("Losses")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.legend()
    else:
        plt.text(0.5, 0.5, "No loss columns found", ha='center')


plt.show()
