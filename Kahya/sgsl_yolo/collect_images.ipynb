# %%
import cv2
import os
import time
import uuid

# Path where images will be saved
images_path = 'dataset/images/train'

# List of labels for which images will be collected
labels = [
    'yes', 'no', 'hello', 'hi', 'how are you', 'i am good',
    'i am ok', 'sorry', 'i love you', 'thank you', 'welcome'
]

# Number of images to collect per label
number_imgs = 30

# Create the main images directory if it doesn't exist
if not os.path.exists(images_path):
    os.makedirs(images_path)

for label in labels:
    print(f'Collecting images for {label}')
    # Create a directory for the current label
    label_path = os.path.join(images_path, label)
    # Create a directory for the current label if it doesn't exist
    if not os.path.exists(label_path):
        os.makedirs(label_path)
    time.sleep(3)  # Allow time to get ready

    # Open the webcam
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        continue
    print(f'Starting collection for {label}')
    time.sleep(3)  # Allow camera to warm up

    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to capture frame.")
            break

        # Generate a unique filename for each image
        imgname = os.path.join(label_path, f'{label}.{uuid.uuid1()}.jpg')
        cv2.imwrite(imgname, frame)
        print(f'Collected image {imgnum + 1} for {label}')
        cv2.imshow('Collecting Images - press Q to quit', frame)
        time.sleep(2)  # Wait before capturing the next image

        # Exit early if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Quitting image collection.")
            break

    cap.release()
    print(f'All images are collected for {label}')
    time.sleep(3)  # Allow time before next label

cv2.destroyAllWindows()
print("Image collection completed for all labels.")
print(f'Images saved in {images_path}')
# Out:
# Collecting images for yes
# Starting collection for yes
# Collected image 1 for yes
# Collected image 2 for yes
# Collected image 3 for yes
# Collected image 4 for yes
# Collected image 5 for yes
# Collected image 6 for yes
# Collected image 7 for yes
# Collected image 8 for yes
# Collected image 9 for yes
# Collected image 10 for yes
# Collected image 11 for yes
# Collected image 12 for yes
# Collected image 13 for yes
# Collected image 14 for yes
# Collected image 15 for yes
# Collected image 16 for yes
# Collected image 17 for yes
# Collected image 18 for yes
# Collected image 19 for yes
# Collected image 20 for yes
# Collected image 21 for yes
# Collected image 22 for yes
# Collected image 23 for yes
# Collected image 24 for yes
# Collected image 25 for yes
# Collected image 26 for yes
# Collected image 27 for yes
# Collected image 28 for yes
# Collected image 29 for yes
# Collected image 30 for yes
# All images are collected for yes
# Collecting images for no
# Starting collection for no
# Collected image 1 for no
# Collected image 2 for no
# Collected image 3 for no
# Collected image 4 for no
# Collected image 5 for no
# Collected image 6 for no
# Collected image 7 for no
# Collected image 8 for no
# Collected image 9 for no
# Collected image 10 for no
# Collected image 11 for no
# Collected image 12 for no
# Collected image 13 for no
# Collected image 14 for no
# Collected image 15 for no
# Collected image 16 for no
# Collected image 17 for no
# Collected image 18 for no
# Collected image 19 for no
# Collected image 20 for no
# Collected image 21 for no
# Collected image 22 for no
# Collected image 23 for no
# Collected image 24 for no
# Collected image 25 for no
# Collected image 26 for no
# Collected image 27 for no
# Collected image 28 for no
# Collected image 29 for no
# Collected image 30 for no
# All images are collected for no
# Collecting images for hello
# Starting collection for hello
# Collected image 1 for hello
# Collected image 2 for hello
# Collected image 3 for hello
# Collected image 4 for hello
# Collected image 5 for hello
# Collected image 6 for hello
# Collected image 7 for hello
# Collected image 8 for hello
# Collected image 9 for hello
# Collected image 10 for hello
# Collected image 11 for hello
# Collected image 12 for hello
# Collected image 13 for hello
# Collected image 14 for hello
# Collected image 15 for hello
# Collected image 16 for hello
# Collected image 17 for hello
# Collected image 18 for hello
# Collected image 19 for hello
# Collected image 20 for hello
# Collected image 21 for hello
# Collected image 22 for hello
# Collected image 23 for hello
# Collected image 24 for hello
# Collected image 25 for hello
# Collected image 26 for hello
# Collected image 27 for hello
# Collected image 28 for hello
# Collected image 29 for hello
# Collected image 30 for hello
# All images are collected for hello
# Collecting images for hi
# Starting collection for hi
# Collected image 1 for hi
# Collected image 2 for hi
# Collected image 3 for hi
# Collected image 4 for hi
# Collected image 5 for hi
# Collected image 6 for hi
# Collected image 7 for hi
# Collected image 8 for hi
# Collected image 9 for hi
# Collected image 10 for hi
# Collected image 11 for hi
# Collected image 12 for hi
# Collected image 13 for hi
# Collected image 14 for hi
# Collected image 15 for hi
# Collected image 16 for hi
# Collected image 17 for hi
# Collected image 18 for hi
# Collected image 19 for hi
# Collected image 20 for hi
# Collected image 21 for hi
# Collected image 22 for hi
# Collected image 23 for hi
# Collected image 24 for hi
# Collected image 25 for hi
# Collected image 26 for hi
# Collected image 27 for hi
# Collected image 28 for hi
# Collected image 29 for hi
# Collected image 30 for hi
# All images are collected for hi
# Collecting images for how are you
# Starting collection for how are you
# Collected image 1 for how are you
# Collected image 2 for how are you
# Collected image 3 for how are you
# Collected image 4 for how are you
# Collected image 5 for how are you
# Collected image 6 for how are you
# Collected image 7 for how are you
# Collected image 8 for how are you
# Collected image 9 for how are you
# Collected image 10 for how are you
# Collected image 11 for how are you
# Collected image 12 for how are you
# Collected image 13 for how are you
# Collected image 14 for how are you
# Collected image 15 for how are you
# Collected image 16 for how are you
# Collected image 17 for how are you
# Collected image 18 for how are you
# Collected image 19 for how are you
# Collected image 20 for how are you
# Collected image 21 for how are you
# Collected image 22 for how are you
# Collected image 23 for how are you
# Collected image 24 for how are you
# Collected image 25 for how are you
# Collected image 26 for how are you
# Collected image 27 for how are you
# Collected image 28 for how are you
# Collected image 29 for how are you
# Collected image 30 for how are you
# All images are collected for how are you
# Collecting images for i am good
# Starting collection for i am good
# Collected image 1 for i am good
# Collected image 2 for i am good
# Collected image 3 for i am good
# Collected image 4 for i am good
# Collected image 5 for i am good
# Collected image 6 for i am good
# Collected image 7 for i am good
# Collected image 8 for i am good
# Collected image 9 for i am good
# Collected image 10 for i am good
# Collected image 11 for i am good
# Collected image 12 for i am good
# Collected image 13 for i am good
# Collected image 14 for i am good
# Collected image 15 for i am good
# Collected image 16 for i am good
# Collected image 17 for i am good
# Collected image 18 for i am good
# Collected image 19 for i am good
# Collected image 20 for i am good
# Collected image 21 for i am good
# Collected image 22 for i am good
# Collected image 23 for i am good
# Collected image 24 for i am good
# Collected image 25 for i am good
# Collected image 26 for i am good
# Collected image 27 for i am good
# Collected image 28 for i am good
# Collected image 29 for i am good
# Collected image 30 for i am good
# All images are collected for i am good
# Collecting images for i am ok
# Starting collection for i am ok
# Collected image 1 for i am ok
# Collected image 2 for i am ok
# Collected image 3 for i am ok
# Collected image 4 for i am ok
# Collected image 5 for i am ok
# Collected image 6 for i am ok
# Collected image 7 for i am ok
# Collected image 8 for i am ok
# Collected image 9 for i am ok
# Collected image 10 for i am ok
# Collected image 11 for i am ok
# Collected image 12 for i am ok
# Collected image 13 for i am ok
# Collected image 14 for i am ok
# Collected image 15 for i am ok
# Collected image 16 for i am ok
# Collected image 17 for i am ok
# Collected image 18 for i am ok
# Collected image 19 for i am ok
# Collected image 20 for i am ok
# Collected image 21 for i am ok
# Collected image 22 for i am ok
# Collected image 23 for i am ok
# Collected image 24 for i am ok
# Collected image 25 for i am ok
# Collected image 26 for i am ok
# Collected image 27 for i am ok
# Collected image 28 for i am ok
# Collected image 29 for i am ok
